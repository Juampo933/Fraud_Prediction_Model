# %% [markdown]
# <a href="https://colab.research.google.com/github/Juampo933/Fraud_Prediction_Model/blob/main/3ra_Entrega_Algoritmos_de_clasificaci%C3%B3n_An%C3%A1lisis_de_Fraudes_Borges_Poggio_Cortez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1ra Entrega Del Proyecto Final:**

# %% [markdown]
# # Análisis de Fraudes:
# ![fp1_301020.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # •	Presentación de la empresa, organización o problema específico:
#
# La empresa es ficticia, pero puede aplicarse a cualquier empresa de seguros, bancarias y financieras, consultoras, asesoras de riesgo e investigación.
# El problema radica en la identificación temprana de posibles fraudes en las miles de transacciones registradas a diario en una organización financiera.
#
#
#
# # •	Preguntas y objetivos de la investigación:
#
# El objetivo del proyecto es comprender qué factores indican que una transacción es fraude o no, y encontrar tendencias dentro de todas estas operaciones, comparándolas también con transacciones que no lo son.
#
#
#
# # •	Conformación del equipo de trabajo:
#
# El equipo de trabajo se conforma por:
# - Valentina Azul
# - Juan Manuel Borges Pons
# - Facundo Cortez
#
#
#
# #•	Indicación de la fuente del dataset y los criterios de selección (Data Acquisition):
#
# La fuente del Dataset se extrajo de la plataforma de Kaggle.
# Es un Dataset cuya finalidad es servir como ejemplo práctico en la detección de fraudes de una compañía.
# Es una matriz de 101.613 filas por 11 columnas
#
#
# * *Entendimiento del caso de Negocio*
#
# •	Qué problema queremos solucionar?
#
# Se busca reducir al máximo posible, la ocurrencia de fraudes en una compañía, verificando que variables pueden servir cómo prevención.
#
# •	¿Qué tipo de datos necesitamos para hacer el análisis?
#
# Los datos requeridos son casi totalmente cuantitativos, en general de carácter numéricos continuos. Se requieren datos referentes a transacciones, montos de las mismas, tipo de operaciones.
#
# •	¿Dónde puedo encontrar estos datos?
#
# Los datos pueden descargarse de la plataforma, o bien del enlace adjunto:
#
# https://www.kaggle.com/gopalmahadevan/fraud-detection-example/activity
#
#
#
# Se eligió este Dataset porque:
# - Presenta un tamaño adecuado (101.613 filas y 11 columnas)
# - Mantiene una distribución uniforme.
# - No tiene datos faltantes ni datos con problemas o nulos.
# - No requiere un proceso exhaustivo de limpieza y ordenamiento de datos
# - Acorde a los objetivos del proyecto.
#
#
#
# #•	Generación del primer Data Wrangling y EDA, apuntado a sus datos (insights) univariado, bivariado y multivariado.
#
# Se procede a exponer el resumen de los 3 diferentes análisis en la parte inferior de este documento.
#
#
# #•	Análisis de componentes principales.
#
# No se realizó análisis de componentes principales, al no estimarlo necesario.
#
#
# #•	Contar la historia de sus datos.
#
#
# - ¿Qué es el análisis del fraude?
#
# La analítica del fraude es el uso de técnicas de análisis de grandes datos para prevenir el fraude financiero en línea. Puede ayudar a las organizaciones financieras a predecir futuros comportamientos fraudulentos y a aplicar una rápida detección y mitigación de la actividad fraudulenta en tiempo real.
#
# Cada año hay más personas que utilizan la banca online o que gestionan sus finanzas por Internet. En 2020, el bloqueo mundial debido a COVID19 convenció a un número aún mayor de clientes de utilizar la banca en línea para al menos una parte de sus actividades financieras. El fraude en línea, que ya aumenta año tras año, ha seguido el mismo camino. La toma de cuentas (ATO), una forma de fraude financiero particularmente popular, se disparó más del 280% entre el segundo trimestre de 2019 y el segundo trimestre de 2020. Las instituciones financieras deben, más que nunca, aplicar medidas integrales de gestión del fraude para proteger las cuentas de sus clientes.
#
#
# - El reto del fraude financiero:
#
# Los bancos y otras instituciones financieras tienen la responsabilidad ante sus clientes de proteger sus datos y finanzas contra el fraude o el robo. Esto se ha convertido en una tarea compleja debido, al menos en parte, a que los clientes pueden acceder a sus cuentas a través de múltiples canales. Pueden realizar sus operaciones bancarias mediante una aplicación de banca móvil, un portal de banca online, llamando al centro de llamadas o incluso visitando el banco en persona.
# Un cajero puede verificar la identidad de un cliente con una confianza razonable. Pero, ¿cómo se puede verificar que la persona que se conecta a una cuenta bancaria en línea es realmente esa persona y no un estafador que se conecta con credenciales robadas? El número de credenciales robadas a disposición de los defraudadores es asombroso. Hay más de 15.000 millones de credenciales robadas a la venta en la web oscura. (...)
#
#
#
# - Casos de uso de la delincuencia financiera:
#
# Toma de posesión de la cuenta: La toma de posesión de la cuenta se produce cuando un estafador utiliza credenciales robadas para acceder a una cuenta en línea existente, por ejemplo, en un banco o comerciante.
#
# Sim Swapping: Se trata de una forma de ATO en la que el estafador utiliza la información personal de la víctima, robada de una filtración de datos o extraída de otras fuentes de información, como las redes sociales, para convencer a la compañía de telefonía móvil de que transfiera el número de teléfono de la víctima al teléfono móvil del estafador.
#
# Phishing: Un ataque de phishing es cuando el estafador se hace pasar por un sitio web legítimo en un correo electrónico o un texto para conseguir que la víctima finalmente divulgue información personal o transfiera fondos.
#
# Malware: Los estafadores utilizan varios métodos, como el phishing, para engañar a la víctima y hacer que cargue un software malicioso en su dispositivo para registrar las pulsaciones del teclado, corromper los datos o inutilizar el dispositivo a menos que se pague un rescate.
#
# Tarjeta no presente (CNP): En el fraude CNP, el estafador utiliza una cuenta de tarjeta de crédito robada para realizar una transacción en la que no se requiere la tarjeta física, por ejemplo, una compra en línea en un sitio de comercio electrónico. Al igual que otras formas de fraude, el fraude con tarjetas de crédito va en aumento.
#
# Ataque de hombre en el medio: Un ataque MitM ocurre cuando un estafador intercepta la comunicación entre un servicio en línea y el cliente con el propósito de robar información o secuestrar la sesión en línea.
# El análisis del fraude es la clave para la gestión del riesgo de fraude financiero
# (...)
#
#
# - Modelos de aprendizaje automático para la detección y prevención del fraude:
#
# El análisis del fraude aplica técnicas de aprendizaje automático a los datos financieros. El aprendizaje automático es un subconjunto de la Inteligencia Artificial (IA). Mientras que la IA es la implementación informática de un pensamiento o proceso de toma de decisiones similar al humano, el aprendizaje automático utiliza técnicas de algoritmos matemáticos para extraer relaciones complejas dentro de los datos analizados. El análisis del fraude utiliza el aprendizaje automático para examinar todos los datos pertinentes relativos a una transacción y asigna una puntuación de riesgo a la misma. En función de la puntuación de riesgo, recomienda permitir la transacción, bloquearla o solicitar una autenticación avanzada antes de permitirla. Y todo esto puede hacerse en tiempo real con o sin intervención humana, lo que proporciona a la entidad financiera una mayor prevención del fraude sin causar una fricción indebida en la sesión del cliente. Cada transacción, desde el inicio de sesión hasta el cierre de la misma, puede ser examinada para detectar posibles riesgos de fraude.
# Un sistema de aprendizaje automático puede ser supervisado o no supervisado. Los modelos de aprendizaje automático no supervisado analizan datos no etiquetados para identificar anomalías entre lo que es habitual y lo que es inusual. El modelo puede entonces detectar relaciones que de otro modo estarían ocultas en los datos para inferir una función o conjunto de instrucciones que describa la estructura y las dimensiones subyacentes de los datos. Esta función o conjunto de instrucciones puede aplicarse entonces a datos nuevos y no vistos para continuar el proceso de aprendizaje.
# Eso es bueno. Pero un modelo supervisado es mejor. Con el aprendizaje automático supervisado, el modelo se entrena utilizando datos etiquetados (datos de fraude y otros datos) y predice la probabilidad de fraude. Se entrena un modelo supervisado presentándole tanto eventos fraudulentos como legítimos y ejecutándolo para desarrollar un conjunto de instrucciones o algoritmo que se aplica a otros ejemplos. El modelo entrenado puede entonces identificar patrones tanto desconocidos como conocidos para producir una puntuación de riesgo precisa para una transacción solicitada.
#
#
# - Técnicas de análisis de big data para combatir el fraude financiero:
#
# La ciencia de los datos es parte de la solución. Las instituciones financieras recopilan enormes cantidades de datos sobre el comportamiento, los dispositivos y las transacciones. El análisis de estos datos por parte del sistema de detección de fraudes y/o del equipo de investigación de fraudes puede utilizarse en la prevención y detección de fraudes financieros. Pero el análisis sólo será tan bueno como los datos del conjunto de datos. Con buenos datos, hay una serie de técnicas de análisis de big data que un sistema de análisis de fraude basado en el aprendizaje automático puede utilizar para combatir el fraude financiero.
#
# El análisis predictivo examina patrones para hacer predicciones sobre eventos futuros, hasta ahora desconocidos, para entender el potencial o la propensión al fraude.
# El reconocimiento de patrones y la detección de anomalías identifican los eventos que no se ajustan a los patrones esperados. Los algoritmos de aprendizaje automático pueden aprender de los datos y hacer predicciones sobre eventos futuros.
# Las herramientas de análisis visual incluyen la unificación de canales digitales, que agrega y supervisa automáticamente las transacciones en busca de actividades sospechosas, la gestión de casos basada en la web para que los analistas de fraudes revisen los casos de fraude y analicen los indicadores clave de fraude, y las herramientas de visualización de fraudes para identificar rápidamente el origen de las transacciones potencialmente fraudulentas.
# El análisis forense, el examen de las causas y consecuencias de un evento de fraude financiero, puede beneficiarse de los datos de análisis visual que proporcionan datos sobre los usuarios, los dispositivos, las ubicaciones, las direcciones IP y las relaciones asociadas a un caso de fraude. El análisis de los datos y las relaciones puede identificar comportamientos potencialmente fraudulentos y exponer la cooperación entre los defraudadores.
# Implantación de una solución de análisis del fraude.
#
# Las instituciones financieras de nivel 2 y 3 no suelen tener grandes equipos de lucha contra el fraude ni grandes recursos para dedicar a la prevención del fraude. Pero necesitan una prevención integral del fraude porque estas instituciones experimentan los mismos casos de uso y escenarios de fraude que las instituciones con operaciones globales. Por lo tanto, es imperativo elegir sabiamente al seleccionar una solución de prevención del fraude. Entre las capacidades clave a tener en cuenta, está la de asegurarse de que su proveedor preferido tiene una profunda experiencia en la prevención del fraude dentro del sector bancario. Evaluar la solución en cuanto a seguridad y controles, escalabilidad y capacidad de la infraestructura. Debe utilizar los últimos análisis avanzados. Además, una solución de prevención del fraude basada en el análisis de riesgos debe cubrir todos los escenarios de las transacciones y admitir la migración de datos históricos.
#
# (...)
#
# Fuente:
# https://www.onespan.com/es/topics/analisis-del-fraude
#
#
#
# #•	Filtros aplicados a los datos. Distribución.
#
# En los diferentes análisis EDA se hicieron algunos filtros y análisis de distribuciones en diferentes variables:
# -	Se uso un filtro en el Grafico de Análisis Multivariado cuando se compararon los montos iniciales y finales de las transacciones, a fin de verificar si eran o no fraude.
# - Se verifico tambien la distribucion de los datos con Histogramas de diferentes variables.
#
#
#
#
# #•	Plantear objetivos para los datos.
#
# Los principales objetivos a priori son:
#
# - Indagar sobre los factores que indiquen que una transacción sea o no fraudulenta.
# - Encontrar tendencias dentro las operaciones que permitan predecir un comportamiento fuera de lugar.
# - Desarrollar un Modelo Analítco Preventivo para tales operaciones.
# - Generar un Sistema de Aprendizaje Supervisado, basado en un Modelo de Clasificación que nos permita predecir transacciones fraudulentas.
#
#
# ```
# # Tiene formato de código
# ```

# %% [markdown]
# # Importación de la Librerías y del Dataset:

# %%
#Importamos las librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FormatStrFormatter

# %%
from google.colab import drive
drive.mount('/content/drive')
df_fraudes=pd.read_csv('/content/drive/MyDrive/Archivos/fraud_dataset_example.csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Introducción y Definicición de las Variables

# %%
df_fraudes.head()
# Out:
#    step      type    amount  ... newbalanceDest  isFraud  isFlaggedFraud
# 0     1   PAYMENT   9839.64  ...            0.0        0               0
# 1     1   PAYMENT   1864.28  ...            0.0        0               0
# 2     1  TRANSFER    181.00  ...            0.0        1               0
# 3     1  CASH_OUT    181.00  ...            0.0        1               0
# 4     1   PAYMENT  11668.14  ...            0.0        0               0
#
# [5 rows x 11 columns]

# %%
type(df_fraudes)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# "
# Content:
#
# - step - unit of time (1 hour)
#
# - type - CASH-IN, CASH-OUT, DEBIT, PAYMENT and TRANSFER.
#
# - amount - transaction amount in local currency.
#
# - nameOrig - transaction originator
#
# - oldbalanceOrg - initial balance (before transaction)
#
# - newbalanceOrig - new balance (after transaction)
#
# - nameDest - transaction recipient
#
# - oldbalanceDest - initial balance before transaction.
#
# - newbalanceDest - new balance after transaction.
#
# - isFraud - Fraud agent takes control of customers accounts and attempts to empty it by transferring to another account and then cashing out.
#
# - isFlaggedFraud - An illegal attempt to transfer massive amount of money in a single transaction.
# "

# %%
df_fraudes.shape
# Out:
# (101613, 11)

# %%
df_fraudes.dtypes
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# dtype: object

# %%
df_fraudes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101613 entries, 0 to 101612
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   step            101613 non-null  int64
#  1   type            101613 non-null  object
#  2   amount          101613 non-null  float64
#  3   nameOrig        101613 non-null  object
#  4   oldbalanceOrg   101613 non-null  float64
#  5   newbalanceOrig  101613 non-null  float64
#  6   nameDest        101613 non-null  object
#  7   oldbalanceDest  101613 non-null  float64
#  8   newbalanceDest  101613 non-null  float64
#  9   isFraud         101613 non-null  int64
#  10  isFlaggedFraud  101613 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 8.5+ MB

# %%
df_fraudes.count()
# Out:
# step              101613
# type              101613
# amount            101613
# nameOrig          101613
# oldbalanceOrg     101613
# newbalanceOrig    101613
# nameDest          101613
# oldbalanceDest    101613
# newbalanceDest    101613
# isFraud           101613
# isFlaggedFraud    101613
# dtype: int64

# %%
df_fraudes.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df_fraudes.describe().T
# Out:
#                    count          mean  ...         75%          max
# step            101613.0  8.523457e+00  ...       10.00        10.00
# amount          101613.0  1.740901e+05  ...   212498.40  10000000.00
# oldbalanceOrg   101613.0  9.071753e+05  ...   194715.00  38939424.03
# newbalanceOrig  101613.0  9.234992e+05  ...   219217.76  38946233.02
# oldbalanceDest  101613.0  8.810428e+05  ...   591921.70  34008736.98
# newbalanceDest  101613.0  1.183998e+06  ...  1063121.64  38946233.02
# isFraud         101613.0  1.141586e-03  ...        0.00         1.00
# isFlaggedFraud  101613.0  0.000000e+00  ...        0.00         0.00
#
# [8 rows x 8 columns]

# %% [markdown]
# # Primeras visualizaciones

# %%
from seaborn import boxplot
from seaborn import distplot

# %% [markdown]
# # Amount:

# %%
df_fraudes.amount.describe().T
# Out:
# count    1.016130e+05
# mean     1.740901e+05
# std      3.450199e+05
# min      3.200000e-01
# 25%      1.001659e+04
# 50%      5.338541e+04
# 75%      2.124984e+05
# max      1.000000e+07
# Name: amount, dtype: float64

# %%
boxplot(df_fraudes.amount)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Los valores estan en Decenas de Millones de USD (1e7 = 10.000.000)

# %%
distplot(df_fraudes.amount)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Oldbalanceorg:

# %%
df_fraudes.oldbalanceOrg.describe().T
# Out:
# count    1.016130e+05
# mean     9.071753e+05
# std      2.829575e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      2.019047e+04
# 75%      1.947150e+05
# max      3.893942e+07
# Name: oldbalanceOrg, dtype: float64

# %%
boxplot(df_fraudes.oldbalanceOrg)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Tampoco ejecutar la sgte celda:

# %%
distplot(df_fraudes.oldbalanceOrg)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Los valores estan en Decenas de Millones de USD (1e7 = 10.000.000)

# %% [markdown]
# # type:

# %%
df_fraudes.type.describe().T
# Out:
# count      101613
# unique          5
# top       PAYMENT
# freq        40062
# Name: type, dtype: object

# %%
sns.countplot(df_fraudes['type'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Las mayorias de las transacciones se generaron en pagos, seguidas por las de cash out, cash in, transferencias y debitos, en ese orden.

# %% [markdown]
# # IsFraud:

# %%
boxplot(df_fraudes.isFraud)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df_fraudes['isFraud'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Análisis Bivariado**

# %%
df_fraudes.head()
# Out:
#    step      type    amount  ...  newbalanceDest  isFraud  isFlaggedFraud
# 0     1   PAYMENT   9839.64  ...             0.0        0               0
# 1     1   PAYMENT   1864.28  ...             0.0        0               0
# 2     1  TRANSFER    181.00  ...             0.0        1               0
# 3     1  CASH_OUT    181.00  ...             0.0        1               0
# 4     1   PAYMENT  11668.14  ...             0.0        0               0
#
# [5 rows x 11 columns]

# %% [markdown]
# # Relaciones:

# %% [markdown]
# # Entre tipo de Transaccion y Monto de la misma:

# %%
sns.scatterplot(df_fraudes['type'], df_fraudes['amount'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# *Podemos visualizar, inicialmente, que las Transferencias y las operaciones de Cash Out tienen montos mucho más altos y variables*
#
# *que las demas operaciones..*

# %%
sns.boxplot(x=df_fraudes['type'], y=df_fraudes['amount'])

# %% [markdown]
# Este gráfico revela en cierta medida, lo mismo que el grafico de puntos de más arriba.

# %% [markdown]
# *Las variable "Transferencias" presenta muchisimos outliers!*

# %% [markdown]
# Tiene una estrecha relación con la funcion describe, ya que encontramos coincidencias con los indicadores estadisticos más utilizados
#
# (media, primer y tercer cuartil, minimos y maximos)

# %%
df_fraudes.describe().T
# Out:
#                    count          mean  ...         75%          max
# step            101613.0  8.523457e+00  ...       10.00        10.00
# amount          101613.0  1.740901e+05  ...   212498.40  10000000.00
# nameOrig             0.0           NaN  ...         NaN          NaN
# oldbalanceOrg   101613.0  9.071753e+05  ...   194715.00  38939424.03
# newbalanceOrig  101613.0  9.234992e+05  ...   219217.76  38946233.02
# nameDest             0.0           NaN  ...         NaN          NaN
# oldbalanceDest  101613.0  8.810428e+05  ...   591921.70  34008736.98
# newbalanceDest  101613.0  1.183998e+06  ...  1063121.64  38946233.02
# isFraud         101613.0  1.141586e-03  ...        0.00         1.00
# isFlaggedFraud  101613.0  0.000000e+00  ...        0.00         0.00
#
# [10 rows x 8 columns]

# %%
agrup_total = df_fraudes[["type", "amount"]].groupby(['type'], as_index=False).sum().sort_values(by='amount', ascending=False)
agrup_total
# Out:
#        type        amount
# 4  TRANSFER  7.570199e+09
# 1  CASH_OUT  6.092313e+09
# 0   CASH_IN  3.585376e+09
# 3   PAYMENT  4.377539e+08
# 2     DEBIT  4.172649e+06

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='type', y='amount', data=agrup_total)

# %%
agrup_promedio = df_fraudes[["type", "amount"]].groupby(['type'], as_index=False).mean().sort_values(by='amount', ascending=False)
agrup_promedio
# Out:
#        type         amount
# 4  TRANSFER  871239.339181
# 1  CASH_OUT  194580.422052
# 0   CASH_IN  174555.795253
# 3   PAYMENT   10926.909680
# 2     DEBIT    4123.170800

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='type', y='amount', data=agrup_promedio)

# %% [markdown]
# Por alguna razon, este codigo tampoco funciona (sí con el scater aunque no es representativo) lo estoy corrigiendo a fin de que funcione.

# %% [markdown]
# # Entre tipo de Transacción y Monto Inicial de la misma:

# %%
sns.scatterplot(df_fraudes['type'], df_fraudes['oldbalanceOrg'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df_fraudes['type'], df_fraudes['newbalanceOrig'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(x=df_fraudes['type'], y=df_fraudes['oldbalanceOrg'])

# %%
sns.boxplot(x=df_fraudes['type'], y=df_fraudes['newbalanceOrig'])

# %% [markdown]
# *Podemos ver en estos pares de graficos que, ambas relaciones con la variable "tipo de operacion"*
#
# *(tanto entre valores iniciales y finales) son bastante similares.*

# %% [markdown]
# # Entre Valores Iniciales y Finales de las Transacciones:

# %%
sns.scatterplot(df_fraudes['oldbalanceOrg'], df_fraudes['newbalanceOrig'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# *Este grafico nos indica una clara y marcada correlacion positiva, aunque la misma no implica bajo ninguna forma dependencia entre las variables*

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Análisis Multivariado**

# %%
df_fraudes.head()
# Out:
#    step      type    amount  ...  newbalanceDest  isFraud  isFlaggedFraud
# 0     1   PAYMENT   9839.64  ...             0.0        0               0
# 1     1   PAYMENT   1864.28  ...             0.0        0               0
# 2     1  TRANSFER    181.00  ...             0.0        1               0
# 3     1  CASH_OUT    181.00  ...             0.0        1               0
# 4     1   PAYMENT  11668.14  ...             0.0        0               0
#
# [5 rows x 11 columns]

# %%
df_fraudes.shape
# Out:
# (101613, 11)

# %%
df_fraudes.describe().T
# Out:
#                    count          mean  ...         75%          max
# step            101613.0  8.523457e+00  ...       10.00        10.00
# amount          101613.0  1.740901e+05  ...   212498.40  10000000.00
# nameOrig             0.0           NaN  ...         NaN          NaN
# oldbalanceOrg   101613.0  9.071753e+05  ...   194715.00  38939424.03
# newbalanceOrig  101613.0  9.234992e+05  ...   219217.76  38946233.02
# nameDest             0.0           NaN  ...         NaN          NaN
# oldbalanceDest  101613.0  8.810428e+05  ...   591921.70  34008736.98
# newbalanceDest  101613.0  1.183998e+06  ...  1063121.64  38946233.02
# isFraud         101613.0  1.141586e-03  ...        0.00         1.00
# isFlaggedFraud  101613.0  0.000000e+00  ...        0.00         0.00
#
# [10 rows x 8 columns]

# %%
df_agrup_tipo = df_fraudes.groupby(['type'])['step'].count().reset_index(name='conteo').sort_values(by='conteo', ascending=False)
df_agrup_tipo
# Out:
#        type  conteo
# 3   PAYMENT   40062
# 1  CASH_OUT   31310
# 0   CASH_IN   20540
# 4  TRANSFER    8689
# 2     DEBIT    1012

# %%
df_agrup_fraude = df_fraudes.groupby(['isFraud'])['step'].count().reset_index(name='conteo').sort_values(by='conteo', ascending=False)
df_agrup_fraude
# Out:
#    isFraud  conteo
# 0        0  101497
# 1        1     116

# %% [markdown]
# # Relaciones entre diferentes Variables:

# %% [markdown]
# Relacionamos tipo de transacciones con los montos de las mismas, y filtramos por si es Fraude o no lo es:

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x='type', y='amount', hue='isFraud', data=df_fraudes)
plt.show()

# %% [markdown]
# *Como se puede visualizar, las transaciones que estan más alejadas en cada tipo de transaccion del Dataset,*
#
# *son consideradas Fraude (color naranja)*

# %% [markdown]
# !

# %% [markdown]
# Analizamos la relación entre los importes iniciales y finales de cada transacción del Dataset, y filtramos por si es Fraude o no:

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x='oldbalanceOrg', y='newbalanceOrig', hue='isFraud',data=df_fraudes)
plt.show()

# %% [markdown]
# *Podemos verificar que la relacion positiva se mantiene a lo largo de todo el Dataset,*
#
# *y los puntos marcados como fraude, son aquellos que estan por fuera de la línea.*

# %% [markdown]
# !

# %% [markdown]
# También podemos filtrar por tipo:

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x='oldbalanceOrg', y='newbalanceOrig', hue='type',data=df_fraudes)
plt.show()

# %% [markdown]
# *Se puede visualizar que las operaciones de "cash in" alcanzan importes iniciales y finales más altos que las demás operaciones.*

# %% [markdown]
# !

# %% [markdown]
# También se puede analizar por Monto de la Transacción:

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x='oldbalanceOrg', y='newbalanceOrig', hue='amount', data=df_fraudes)
plt.show()

# %% [markdown]
# *Este gráfico nos resulta muy útil porque podemos ver claramente que, las transacciones con montos más altos (color más oscuro)*
#
# *son aquellas fuera de la relación (que tambien son consideradas como Fraude)*

# %% [markdown]
# !!!

# %% [markdown]
# **Por último, también podemos visualizar un grafico con las 4 variables más importantes!**

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x='oldbalanceOrg', y='newbalanceOrig', hue='type', style='isFraud', data=df_fraudes)
plt.show()

# %% [markdown]
# *Se puede verificar un análisis consistente con los graficos anteriores.*

# %% [markdown]
# # Cambio de Tipo de Datos de las Variables:

# %% [markdown]
# Procedemos a cambiar el tipo de datos de algunas variables a fin de utilizar los modelos:

# %%
df_fraudes.dtypes
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# dtype: object

# %%
df_fraudes['nameOrig'] = pd.to_numeric(df_fraudes['nameOrig'],errors = 'coerce')

# %%
df_fraudes['oldbalanceOrg'] = pd.to_numeric(df_fraudes['oldbalanceOrg'],errors = 'coerce')

# %%
df_fraudes['newbalanceOrig'] = pd.to_numeric(df_fraudes['newbalanceOrig'],errors = 'coerce')

# %%
df_fraudes['nameDest'] = pd.to_numeric(df_fraudes['nameDest'],errors = 'coerce')

# %%
df_fraudes['oldbalanceDest'] = pd.to_numeric(df_fraudes['oldbalanceDest'],errors = 'coerce')

# %%
df_fraudes['newbalanceDest'] = pd.to_numeric(df_fraudes['newbalanceDest'],errors = 'coerce')

# %%
df_fraudes.dtypes
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig          float64
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest          float64
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# dtype: object

# %% [markdown]
# # **2da Entrega del Proyecto Final**

# %% [markdown]
# Luego de haber realizado el Análisis Exploratorio de Datos procedemos a:
#
#  * Verificar las relaciones entre las Variables
#
#  * Analizar las implicancias de un Dataset Desbalanceado
#
#  * Implementar un Modelo de Clasificacion
#
#  * Verificar las metricas del mismo.

# %%
df_fraudes.head()
# Out:
#    step      type    amount  ... newbalanceDest  isFraud  isFlaggedFraud
# 0     1   PAYMENT   9839.64  ...            0.0        0               0
# 1     1   PAYMENT   1864.28  ...            0.0        0               0
# 2     1  TRANSFER    181.00  ...            0.0        1               0
# 3     1  CASH_OUT    181.00  ...            0.0        1               0
# 4     1   PAYMENT  11668.14  ...            0.0        0               0
#
# [5 rows x 11 columns]

# %%
df_fraudes.isFlaggedFraud.sum()
# Out:
# 0

# %% [markdown]
# Procedemos a eliminar del Dataset las variables:
# - Step (no aporta información relevante)
# - isFlaggedFraud (todos valores =0)
# - NameDest
# - NameOrig
#
# A fin de prepararlo para la aplicacion del Modelo de Machine Learning.

# %%
df_fraudes = df_fraudes.drop(["step", "isFlaggedFraud", "nameDest", "nameOrig"], axis = 1)

# %%
df_fraudes.head()
# Out:
#        type    amount  oldbalanceOrg  ...  oldbalanceDest  newbalanceDest  isFraud
# 0   PAYMENT   9839.64       170136.0  ...             0.0             0.0        0
# 1   PAYMENT   1864.28        21249.0  ...             0.0             0.0        0
# 2  TRANSFER    181.00          181.0  ...             0.0             0.0        1
# 3  CASH_OUT    181.00          181.0  ...         21182.0             0.0        1
# 4   PAYMENT  11668.14        41554.0  ...             0.0             0.0        0
#
# [5 rows x 7 columns]

# %% [markdown]
# # **Matriz de Correlación:**

# %%
plt.figure(figsize=(14,7))
sns.heatmap(df_fraudes.corr(), annot=True)

# %% [markdown]
# Como podemos verificar las relaciones son más fuertes entre:
#
# * OldbalanceOrg y NewbalanceOrg recíprocamente: es decir entre los montos iniciales y finales de las cuentas donde se **originan** las transacciones.
#
# * OldbalanceDest y NewbalanceDest recíprocamente: es decir entre los montos iniciales y finales de las cuentas **destino** de las transacciones.

# %% [markdown]
# Las demás relaciones son más débiles.

# %% [markdown]
# # Clasificación con Datasets Desbalanceados:

# %%
#

# %% [markdown]
# ¿Qué son los problemas de clasificación de Clases desequilibradas? (imbalanced data)
#
#
# ---
#
#
#
# En los problemas de clasificación en donde tenemos que etiquetar por ejemplo entre “spam” o “not spam” ó entre múltiples categorías (coche, barco, avión) solemos encontrar que en nuestro conjunto de datos de entrenamiento contamos con que alguna de las clases de muestra es una clase “minoritaria” es decir, de la cual tenemos muy poquitas muestras. Esto provoca un desbalanceo en los datos que utilizaremos para el entrenamiento de nuestra máquina.
#
# Un caso evidente es en el área de Salud en donde solemos encontrar conjuntos de datos con miles de registros con pacientes “negativos” y unos pocos casos positivos es decir, que padecen la enfermedad que queremos clasificar.
#
#
# ***Otros ejemplos suelen ser los de Detección de fraude donde tenemos muchas muestras de clientes “honestos” y pocos casos etiquetados como fraudulentos. Ó en un funnel de marketing, en donde por lo general tenemos un 2% de los datos de clientes que “compran” ó ejecutan algún tipo de acción (CTA) que queremos predecir.***
#
#
#
# ---
#
# ¿Cómo nos afectan los datos desbalanceados?
#
#
# ---
#
#
# Por lo general afecta a los algoritmos en su proceso de generalización de la información y perjudicando a las clases minoritarias. Esto suena bastante razonable: si a una red neuronal le damos 990 de fotos de gatitos y sólo 10 de perros, no podemos pretender que logre diferenciar una clase de otra. Lo más probable que la red se limite a responder siempre “tu foto es un gato” puesto que así tuvo un acierto del 99% en su fase de entrenamiento.

# %% [markdown]
# https://www.aprendemachinelearning.com/clasificacion-con-datos-desbalanceados/

# %% [markdown]
# # **Implementación: Desbalanceo de Clases**

# %%
df_fraudes.head()
# Out:
#        type    amount  oldbalanceOrg  ...  oldbalanceDest  newbalanceDest  isFraud
# 0   PAYMENT   9839.64       170136.0  ...             0.0             0.0        0
# 1   PAYMENT   1864.28        21249.0  ...             0.0             0.0        0
# 2  TRANSFER    181.00          181.0  ...             0.0             0.0        1
# 3  CASH_OUT    181.00          181.0  ...         21182.0             0.0        1
# 4   PAYMENT  11668.14        41554.0  ...             0.0             0.0        0
#
# [5 rows x 7 columns]

# %% [markdown]
# **Podemos verificar cuantos de nuestros operaciones son efectivamente fraudes:**

# %%
df_fraudes.isFraud.sum()
# Out:
# 116

# %%
print(df_fraudes.shape)
print(pd.value_counts(df_fraudes['isFraud'], sort = True))
# Out:
# (101613, 7)
# 0    101497
# 1       116
# Name: isFraud, dtype: int64

# %%
plt.figure(figsize=(3,6))

count_classes = pd.value_counts(df_fraudes['isFraud'], sort = True)
count_classes.plot(kind = 'bar', rot=1)
plt.title("Fraudes vs No Fraudes")
plt.xlabel("isFraud")
plt.ylabel("Operaciones");

# %% [markdown]
# Relacionando con lo que indicamos más arriba, en nuestro caso básicamente tendremos:
# -  1 clase mayoritaria (las 101.497 operaciones normales, clase 0) y,
# - 1 clase minoritaria ( las 116 operaciones de fraude que se intentan prevenir, clase 1)

# %% [markdown]
# Mediante este procedimiento podemos verificar lo que indicamos más arriba.
#
# La variable más importante que repercute en nuestro modelo es "amount", es decir el monto de la operación.

# %% [markdown]
# # Algoritmos de Clasificación: Partición de los vectores y División en Train y Test:

# %% [markdown]
# Cargamos las librerias correspondientes:

# %%
import urllib.request
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# Separamos las variables dependientes e independientes

# %%
#Separamos en X e Y
x = df_fraudes.drop(["isFraud", "type"], axis=1) #Elimino del dataset la variables object y la variable independiente
y = df_fraudes.isFraud                           #Me quedo con la variable de salida

# %% [markdown]
# **Vamos a estandarizar los datos del vector "x" para un correcto funcionamiento del modelo:**

# %%
from sklearn.preprocessing import StandardScaler
scl = StandardScaler()
X = scl.fit_transform(x)

# %%
#Libreria para separar en train y test
from sklearn.model_selection import train_test_split

# %% [markdown]
# Usamos el 70% para train y el 30% para test:

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
y_test.sum()
# Out:
# 32

# %% [markdown]
# Queremos predecir 32 fraudes en nuestra variable de salida, sólo contando los datos de test.

# %% [markdown]
# # **Árbol de Decisión Simple:**

# %% [markdown]
# **Creamos un Arbol de Decisión simple:**

# %%
tree = DecisionTreeClassifier(max_depth=2 , random_state=11)

# %% [markdown]
# Lo entrenamos con los datos de Entrenamiento:

# %%
tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=11)

# %% [markdown]
# Usamos el modelo para predecir en base a X Test

# %%
y_train_pred = tree.predict(x_train)
y_test_pred = tree.predict(x_test)

# %% [markdown]
# Podemos, con fines prácticos, generar un dataframe con la diferencia en los valores de ambos vectores.
#
# Es decir, una tabla que indique que valor fue el que realmente se encontró en el dataset y el que el modelo de Árbol logró predecir.
#
# Solo lo haremos con el vector de test, que es el que nos interesa verificar.

# %%
df_dif = pd.DataFrame({'y_test':y_test ,'y_test_pred':y_test_pred})
df_dif.head()
# Out:
#        y_test  y_test_pred
# 690         0            0
# 46856       0            0
# 87115       0            0
# 57005       0            0
# 40495       0            0

# %% [markdown]
# Podemos consultarla también con fines de corroborar las métricas en cualquier momento.

# %% [markdown]
# Utilizamos la métrica de accuracy, comparando "*y_train*" vs "*y_train_pred*", para Train y Test.

# %%
train_accuracy = accuracy_score(y_train, y_train_pred)
print('% de aciertos sobre el set de entrenamiento:', train_accuracy)

test_accuracy = accuracy_score(y_test, y_test_pred)
print('% de aciertos sobre el set de evaluación:', test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 0.9988752829366363
# % de aciertos sobre el set de evaluación: 0.9989502689935704

# %% [markdown]
# Verificamos que el modelo responde bien a los datos de entrenamiento, y también a los datos de testeo.
#
# Como resulta muy cercano a 1, este modelo podría estar presentando Overfitting.
#
# Incluso con la implementacion del Árbol simple, se generaron buenos resultados.

# %% [markdown]
# **Implementamos también una Matriz de Confusión para verificar las métricas:**

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_pred)

print("Matriz de Conf.")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")
# Out:
# Matriz de Conf.
#
# [[30452     0]
#  [   32     0]]
#
#  [VN  FP  ]
#  [FN  VP  ]

# %% [markdown]
# Podemos verificar que el modelo arrojó:
#
# - Que 30452 operaciones no serían fraude, y no lo fueron.
# - Que en ninguna operacion el sistema indicó que era fraude, aunque no hubieram sido fraude
# - Que 32 operaciones no serían fraude, pero en realidad sí lo fueron. **(!)**
# - Que no predijo operaciones como fraude, a pesar de que no lo fueron.

# %%
df_dif.head()
# Out:
#        y_test  y_test_pred
# 690         0            0
# 46856       0            0
# 87115       0            0
# 57005       0            0
# 40495       0            0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 4))

importances = tree.feature_importances_
columns = x.columns
sns.barplot(columns, importances)
plt.title('Importancia de cada Feature')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# !!!

# %% [markdown]
# # **Métricas**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Recordemos que el Accuracy es el porcentaje de aciertos de mi Modelo sobre el Total de Observaciones.
#
# Es decir, los VP, aquellas operaciones que el modelo predijo que serían fraude y lo fueron efectivamente; y los VN, aquellos que el modelo predijo que no serían fraude y no lo fueron; sobre el total de transacciones.

# %% [markdown]
# ***Es un buen indicador a nivel general, pero no debemos quedarnos sólo con él.***

# %% [markdown]
# **! Precisión:**

# %% [markdown]
# En cambio, la Precision (de la clase 1 en este caso) hace referencia a que tan confiable es el modelo en asignar una operacion a una clase o a otra.
#
# Es decir, que representa el total de aciertos de casos positivos (predicciones positivas correctas sobre fraudes) sobre todos los casos donde ***el modelo predijo*** que era fraude (predicciones positivas correctas e incorrectas sobre los fraudes)
#
# *En este caso estamos dandole más importancia a los Falsos Positivos, queremos reducirlos al máximo.*
#
# *Supongamos para este caso, que la empresa no quiera que sus clientes se vean frustrados al no poder hacer transacciones correctamente cuando el modelo detecta un montón de casos de fraude cuando no lo son.*

# %% [markdown]
# ! **Recall:**

# %% [markdown]
# **Asimismo, el Recall (de la clase 1) expresa cuan bien puede el modelo detectar a esa clase.**

# %% [markdown]
# Es decir, que representa el total de aciertos de casos positivos (predicciones positivas correctas sobre fraudes) sobre ***todos los casos donde realmente hubo fraude*** (predicciones positivas correctas y negativas incorrectas sobre los fraudes)

# %% [markdown]
# En este caso estamos dandole más importancia a los Falsos Negativos, queremos reducirlos al máximo posible.
#
# En la Deteccion de Fraudes cobra vital importancia los Falsos Negativos.
#
# **De nuevo, son operaciones que el sistema clasificó como normales pero eran fraudulentas.**
#
# *En este caso, es entendible que la empresa no va a utilizar un modelo en donde las operaciones que sean fraudulentas "se filtren" entre las normales,  perjudicando a los clientes y a la operatoria de la misma.*

# %% [markdown]
# ---
#
#
#
# **Por lo tanto, en este caso, debemos priorizar el Recall o Recuperación como métrica para medir la calidad de nuestro clasificador en general.**
#
# ---

# %% [markdown]
# Además:

# %% [markdown]
# Tenemos cuatro casos posibles para cada clase:
#
# Alta precision y alto recall: el modelo maneja perfectamente esa clase
#
# Alta precision y bajo recall: el modelo no detecta la clase muy bien, pero cuando lo hace es altamente confiable.
#
# Baja precisión y alto recall: La clase detecta bien la clase pero también incluye muestras de otras clases.
#
# Baja precisión y bajo recall: El modelo no logra clasificar la clase correctamente.
#
#
# ***Cuando tenemos un dataset con desequilibrio, suele ocurrir que obtenemos un alto valor de precisión en la clase Mayoritaria y un bajo recall en la clase Minoritaria***

# %% [markdown]
# # **Arboles de Decision con diferente profundidad: "max_depth"**

# %%
tree2 = DecisionTreeClassifier(max_depth=8 , random_state=11)

# %%
tree2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=8, random_state=11)

# %%
y_train_pred2 = tree2.predict(x_train)
y_test_pred2 = tree2.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

train_accuracy = accuracy_score(y_train, y_train_pred2)
print('% de aciertos sobre el set de entrenamiento:', train_accuracy)

test_accuracy = accuracy_score(y_test, y_test_pred2)
print('% de aciertos sobre el set de evaluación:', test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 0.9991424032391851
# % de aciertos sobre el set de evaluación: 0.9990158771814722

# %%
from sklearn.metrics import recall_score

print(f"Recall Score of the classifier is: {recall_score(y_test, y_test_pred2)}")
# Out:
# Recall Score of the classifier is: 0.125

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_pred2)

print("Matriz de Conf.")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")
# Out:
# Matriz de Conf.
#
# [[30450     2]
#  [   28     4]]
#
#  [VN  FP  ]
#  [FN  VP  ]

# %% [markdown]
# ***Vereificamos que con una mayor profundidad en el "max_depth" se incrementaron los VP, por lo que mejoró sustancialmente el Accuracy***

# %% [markdown]
# Probamos con 13 de max_depth

# %%
tree3 = DecisionTreeClassifier(max_depth=13 , random_state=11)

# %%
tree3.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=13, random_state=11)

# %%
y_train_pred3 = tree3.predict(x_train)
y_test_pred3 = tree3.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

train_accuracy = accuracy_score(y_train, y_train_pred3)
print('% de aciertos sobre el set de entrenamiento:', train_accuracy)

test_accuracy = accuracy_score(y_test, y_test_pred3)
print('% de aciertos sobre el set de evaluación:', test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 0.9998312924404954
# % de aciertos sobre el set de evaluación: 0.999114289463325

# %%
from sklearn.metrics import recall_score

print(f"Recall Score of the classifier is: {recall_score(y_test, y_test_pred3)}")
# Out:
# Recall Score of the classifier is: 0.5625

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_pred3)

print("Matriz de Conf.")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")
# Out:
# Matriz de Conf.
#
# [[30439    13]
#  [   14    18]]
#
#  [VN  FP  ]
#  [FN  VP  ]

# %% [markdown]
# ***Con una profundidad en el "max_depth" de 13, se llegó al mejor Accuracy***

# %% [markdown]
# Deberíamos tratar, al menos, de reducir tanto como sea posible los FN, ya que estos casos indicarian que el sistema indicó que la operación no era un Fraude, cuando en realidad sí lo fué, por lo que terminaría "dejando pasar" a las operaciones de este tipo, lo que es perjudicial para nuestros objetivos.
#
# Sería mucho más aceptable para la empresa, notificar un FP, es decir una operacion que supuestamente era Fraude pero que en realidad no lo es.

# %% [markdown]
# A fin de reducir los FN y aumentar los VP tanto como sea posible, utilizaremos el parámetro:  class_weight="balanced" ya que contamos con muy pocos datos de clase 1 (Fraude) en comparacion con los de clase 0 (Normal)

# %% [markdown]
# # **Arbol de Decision con clase minoritaria balanceada: "class_weight="balanced"**

# %%
tree_balaced = DecisionTreeClassifier(max_depth=8 , random_state=11, class_weight="balanced")

# %%
tree_balaced.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=8, random_state=11)

# %%
y_train_pred_bal = tree_balaced.predict(x_train)
y_test_pred_bal = tree_balaced.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

train_accuracy = accuracy_score(y_train, y_train_pred_bal)
print('% de aciertos sobre el set de entrenamiento:', train_accuracy)

test_accuracy = accuracy_score(y_test, y_test_pred_bal)
print('% de aciertos sobre el set de evaluación:', test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 0.9825528265545699
# % de aciertos sobre el set de evaluación: 0.9835651489305866

# %%
from sklearn.metrics import recall_score

print(f"Recall Score of the classifier is: {recall_score(y_test, y_test_pred_bal)}")
# Out:
# Recall Score of the classifier is: 0.84375

# %% [markdown]
# ***Aumentamos bastante el Recall!!!***
#
# **De 0.12 a 0.56, y ahora 0.84!**

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_pred_bal)

print("Matriz de Conf.")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")
# Out:
# Matriz de Conf.
#
# [[29956   496]
#  [    5    27]]
#
#  [VN  FP  ]
#  [FN  VP  ]

# %% [markdown]
# Con este modelo de Arbol de Decision, pero modificado por el parámetro: class_weight="balanced", obtuvimos un mejor resultado que en los anteriores (sin importar la profundidad

# %% [markdown]
# # **Aplicación del Random Forest:**

# %% [markdown]
# ***Creamos un Random Forest con sus parámetros y lo entrenamos:***

# %%
modelR = RandomForestClassifier(random_state=11, n_estimators=200,
                               class_weight="balanced", max_features="log2")
modelR.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_features='log2',
#                        n_estimators=200, random_state=11)

# %% [markdown]
# Prediccion en Train y en Test :

# %%
y_train_pred_R = modelR.predict(x_train)
y_test_pred_R = modelR.predict(x_test)

# %% [markdown]
# Accuracy en Train y en Test:

# %%
from sklearn.metrics import accuracy_score

train_accuracy_R = accuracy_score(y_train, y_train_pred_R)
print('% de aciertos sobre el set de entrenamiento:',train_accuracy_R)


test_accuracy_R = accuracy_score(y_test, y_test_pred_R)
print('% de aciertos sobre el set de evaluación:',test_accuracy_R)
# Out:
# % de aciertos sobre el set de entrenamiento: 1.0
# % de aciertos sobre el set de evaluación: 0.9990814853693741

# %%
from sklearn.metrics import recall_score

print(f"Recall Score of the classifier is: {recall_score(y_test, y_test_pred_R)}")
# Out:
# Recall Score of the classifier is: 0.15625

# %% [markdown]
# El valor de Accuracy y Recall no cambio sustancialmente con el Random Forest.

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_pred_R)

print("Matriz de Conf.")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")
# Out:
# Matriz de Conf.
#
# [[30451     1]
#  [   27     5]]
#
#  [VN  FP  ]
#  [FN  VP  ]

# %% [markdown]
# Verificamos tambien la Matriz de Confusión, con el Modelo de Random Forest aumentaron los VP, detectando los verdaderos fraudes, y redujo un poco los FN, donde tildaba de "no fraude" aquellos que sí lo eran.

# %% [markdown]
# # **Random Forest con mayor número de estimators:**

# %%
modelR2 = RandomForestClassifier(random_state=11, n_estimators=500,
                               class_weight="balanced", max_features="log2")

# %%
modelR2.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_features='log2',
#                        n_estimators=500, random_state=11)

# %%
y_train_pred_R2 = modelR2.predict(x_train)
y_test_pred_R2 = modelR2.predict(x_test)

# %%
train_accuracy = accuracy_score(y_train, y_train_pred_R2)
print('% de aciertos sobre el set de evaluación:',train_accuracy)


test_accuracy = accuracy_score(y_test, y_test_pred_R2)
print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de evaluación: 1.0
# % de aciertos sobre el set de evaluación: 0.9990814853693741

# %%
from sklearn.metrics import recall_score

print(f"Recall Score of the classifier is: {recall_score(y_test, y_test_pred_R2)}")
# Out:
# Recall Score of the classifier is: 0.15625

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_pred_R2)

print("Matriz de Conf.")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")
# Out:
# Matriz de Conf.
#
# [[30451     1]
#  [   27     5]]
#
#  [VN  FP  ]
#  [FN  VP  ]

# %% [markdown]
# # Aplicación de Hypertunning en Random Forest con Grid Search Cv

# %% [markdown]
# (estas celdas demoran en ejecutarse, aprox 20 minutos)

# %%
#Hypertuning utilizando grid search
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier() #Instanciamos el modelo

# %%
#Definimos los parámetros de búsqueda
params = {
    'n_estimators' : [100, 200, 500],
    'max_features': [2,3]
}

grid_random_forest = GridSearchCV(estimator = random_forest,
                                  param_grid = params,
                                  scoring = 'neg_mean_absolute_error',  # 
                                  cv = 5, 
                                  verbose = 1, #Muestra el resultado en pantalla
                                  n_jobs = -1) # corrida en paralelo

# %%
grid_random_forest = GridSearchCV(estimator = random_forest,
                                  scoring = 'neg_mean_absolute_error',  # 
                                  cv = 5, 
                                  verbose = 1, #Muestra el resultado en pantalla
                                  n_jobs = -1) # corrida en paralelo

# %%
#Entrenamos el modelo
grid_random_forest.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_features': [2, 3],
#                          'n_estimators': [100, 200, 500]},
#              scoring='neg_mean_absolute_error', verbose=1)

# %%
#Obtenemos el mejor modelo!
grid_random_forest.best_estimator_
# Out:
# RandomForestClassifier(max_features=3)

# %%
#Predicción de casos nuevos
y_train_pred_RF_GSC = grid_random_forest.predict(x_train)
y_test_pred_RF_GSC = grid_random_forest.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_pred_RF_GSC)

print("Matriz de Conf.")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")
# Out:
# Matriz de Conf.
#
# [[30451     1]
#  [   24     8]]
#
#  [VN  FP  ]
#  [FN  VP  ]

# %% [markdown]
# ***Con Hypertuning tambien obtuvimos buenos resultados, pero no se acercan a lo que es el Arbol de Decision con clase minoritaria balanceada.***

# %% [markdown]
# # KNN (distinto numero de vecinos)

# %% [markdown]
# Probamos con 3 vecinos cercanos:

# %%
#importamos la libreria
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_train_predict_KNN = knn.predict(x_train)
y_test_predict_KNN = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score_train_KNN = accuracy_score(y_train, y_train_predict_KNN)
print("% de accuracy en los datos de entrenamiento", accuracy_score_train_KNN)

accuracy_score_test_KNN = accuracy_score(y_test, y_test_predict_KNN)
print("% de accuracy en los datos de testeo", accuracy_score_test_KNN)
# Out:
# % de accuracy en los datos de entrenamiento 0.9990299315328488
# % de accuracy en los datos de testeo 0.9989174648996195

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_predict_KNN)

print("Matriz de Conf.")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")
# Out:
# Matriz de Conf.
#
# [[30447     5]
#  [   28     4]]
#
#  [VN  FP  ]
#  [FN  VP  ]

# %% [markdown]
# Se obtuvieron mejores resultados, pero aún siguen siendo elevados los FN, que queremos reducir.

# %% [markdown]
# Probamos con distintos valores de K, "menor cantidad de vecinos":

# %%
knn2 = KNeighborsClassifier(n_neighbors=1)
knn2.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_train_predict_KNN2 = knn2.predict(x_train)
y_test_predict_KNN2 = knn2.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score_train_KNN = accuracy_score(y_train, y_train_predict_KNN2)
print("% de accuracy en los datos de entrenamiento", accuracy_score_train_KNN)


accuracy_score_test_KNN = accuracy_score(y_test, y_test_predict_KNN2)
print("% de accuracy en los datos de testeo", accuracy_score_test_KNN)
# Out:
# % de accuracy en los datos de entrenamiento 1.0
# % de accuracy en los datos de testeo 0.9979005379871408

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_predict_KNN2)

print("Matriz de Conf.")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")
# Out:
# Matriz de Conf.
#
# [[30415    37]
#  [   27     5]]
#
#  [VN  FP  ]
#  [FN  VP  ]

# %% [markdown]
# # **Regresión Logística**

# %% [markdown]
# Recordemos que este modelo, no es un Algoritmo de Regresión, sino de Clasificación.
#
# Trabaja con probabilidades de ocurrencia.
# Si el modelo estima que las probabilidades de que suceda un Fraude superan el 50 % las clasificará como Fraude, de lo contrario como transacciones normales.

# %%
#importamos la clase LogisticRegresion de scikit-learn
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Generamos una instancia de la Regresión Logística:

# %%
reg_log = LogisticRegression(C=1.0,penalty='l2',random_state=1,solver="newton-cg")

# %% [markdown]
# Entrenamos la regresión logística con los datos de entrenamiento

# %%
reg_log.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=1, solver='newton-cg')

# %% [markdown]
# Hacemos las predicciones y verificamos las métricas:

# %%
y_train_predict_RL = reg_log.predict(x_train)
y_test_predict_RL = reg_log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score_train_RL = accuracy_score(y_train, y_train_predict_RL)
print("% de accuracy en los datos de entrenamiento", accuracy_score_train_RL)

accuracy_score_test_RL = accuracy_score(y_test, y_test_predict_RL)
print("% de accuracy en los datos de testeo", accuracy_score_test_RL)
# Out:
# % de accuracy en los datos de entrenamiento 0.9988752829366363
# % de accuracy en los datos de testeo 0.9989502689935704

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_predict_RL)

print("Matriz de Confusión para RL")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")

print (classification_report(y_test, y_test_predict_RL))
# Out:
# Matriz de Confusión para RL
#
# [[30452     0]
#  [   32     0]]
#
#  [VN  FP  ]
#  [FN  VP  ]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     30452
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00     30484
#    macro avg       0.50      0.50      0.50     30484
# weighted avg       1.00      1.00      1.00     30484
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# Sin ningún tipo de modificacion en los parámetros vemos que los resultados son pésimos.

# %% [markdown]
# # **Regresión Logística con weight = “balanced”.**

# %%
#importamos la clase LogisticRegresion de scikit-learn
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# En este caso utilizaremos un ***parámetro adicional*** en el modelo de Regresión logística en donde indicamos weight = “balanced”.
#
# La idea es que el algoritmo se encargará de equilibrar a la clase minoritaria durante el entrenamiento. Veamos:

# %%
reg_log_bal = LogisticRegression(C=1.0,penalty='l2',random_state=1,solver="newton-cg",class_weight="balanced")

# %% [markdown]
# Entrenamos y predecimos.

# %%
reg_log_bal.fit(x_train, y_train)

y_train_predict_RLbal = reg_log_bal.predict(x_train)
y_test_predict_RLbal = reg_log_bal.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score_train_RL = accuracy_score(y_train, y_train_predict_RL)
print("% de accuracy en los datos de entrenamiento", accuracy_score_train_RL)

accuracy_score_test_RL = accuracy_score(y_test, y_test_predict_RL)
print("% de accuracy en los datos de testeo", accuracy_score_test_RL)
# Out:
# % de accuracy en los datos de entrenamiento 0.9988752829366363
# % de accuracy en los datos de testeo 0.9989502689935704

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_test_predict_RLbal)

print("Matriz de Confusión para RL")
print("")
print(matriz)
print("")
print(" [VN  FP  ]")
print(" [FN  VP  ]")

print (classification_report(y_test, y_test_predict_RLbal))
# Out:
# Matriz de Confusión para RL
#
# [[20774  9678]
#  [    0    32]]
#
#  [VN  FP  ]
#  [FN  VP  ]
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81     30452
#            1       0.00      1.00      0.01        32
#
#     accuracy                           0.68     30484
#    macro avg       0.50      0.84      0.41     30484
# weighted avg       1.00      0.68      0.81     30484

# %% [markdown]
# ***Este es uno de los mejores resultados que obtuvimos hasta ahora, o al menos el más seguro.***
#
# ***Ya que no tenemos FN, que son los que queriamos reducir.***

# %% [markdown]
# ***Sin embargo los FP se incrementaron exponencialmente por lo que merecen atención.***

# %% [markdown]
# # **3ra Entrega del Proyecto Final**

# %% [markdown]
# El algoritmo elegido para nuestro caso de análisis será el de Regresión Logística con weight = “balanced”, ya que el mismo:
# - Presenta buenos resultados en las métricas de accuraccy, precision y recall.
# - No clasifica ninguna operacion como normal cuando la misma hubiera sido fraude (no presenta FN)
# - A pesar de que presenta muchos casos donde se predice un fraude cuando en realidad es una operación normal (FP) éstos no son significativos para el negocio en cuestión.

# %%
#importamos la clase LogisticRegresion de scikit-learn
from sklearn.linear_model import LogisticRegression

reg_log_bal = LogisticRegression(C=1.0,penalty='l2',random_state=1,solver="newton-cg",class_weight="balanced")

reg_log_bal.fit(x_train, y_train)

y_train_predict_RLbal = reg_log_bal.predict(x_train)
y_test_predict_RLbal = reg_log_bal.predict(x_test)

print (classification_report(y_test, y_test_predict_RLbal))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81     30452
#            1       0.00      1.00      0.01        32
#
#     accuracy                           0.68     30484
#    macro avg       0.50      0.84      0.41     30484
# weighted avg       1.00      0.68      0.81     30484
